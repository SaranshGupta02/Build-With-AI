# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL to scrape
url = 'https://www.buildfastwithai.com/resources'

# Send a GET request
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# List to store data
data = []

# Locate each resource entry by the outermost `a` tag class
for resource in soup.find_all('a', class_='hover:scale-105 duration-200'):
    # Extract course page link
    resource_link = 'https://www.buildfastwithai.com' + resource['href']
    
    # Extract poster image URL from <img>
    img_tag = resource.find('img')
    poster_url = img_tag['src'] if img_tag else ''
    
    # Extract course name
    course_name_tag = resource.find('p', class_='text-xl font-semibold text-foreground')
    course_name = course_name_tag.get_text(strip=True) if course_name_tag else 'Unknown'
    
    # Extract description (optional based on availability)
    description_tag = resource.find('p', class_='mt-3 line-clamp-5 text-sm text-muted-foreground md:text-base')
    description = description_tag.get_text(strip=True) if description_tag else 'No description'
    
    # Extract price label or availability
    price_tag = resource.find('div', class_='rounded-full px-3 py-1 bg-muted text-xs')
    price = price_tag.get_text(strip=True) if price_tag else 'Unknown'
    
    # Add to data list
    data.append({
        'Course Name': course_name,
        'Poster Image URL': poster_url,
        'Resource Link': resource_link,
        'Description': description,
        'Price': price
    })

# Convert to DataFrame
df = pd.DataFrame(data)

# Save to CSV
df.to_csv('resources_dataset.csv', index=False)

print("Data scraped and saved to resources_dataset.csv")
# Out:
# Data scraped and saved to resources_dataset.csv

# %%
df=pd.read_csv("resources_dataset.csv")

# %%
df
# Out:
#                                          Course Name  \
# 0                   Are you Ready for GenAI in 2025?
# 1                   Build Website in just 20 Minutes
# 2                          Master Automation with AI
# 3                        Elevate Your Resume with AI
# 4                                 Coding with Cursor
# 5                          Create Your Own AI Avatar
# 6                                   Gen AI for Excel
# 7                        Basics of Python for Gen AI
# 8                          Create Your AI Girlfriend
# 9                     Gen AI 2024 Half-yearly Rewind
# 10                                 Claude 3.5 Sonnet
# 11                              Web Scraping with AI
# 12                         Function Calling with LLM
# 13                                 GPT-4o: Deep Dive
# 14                10x Developer Productivity with AI
# 15                               Llama 3 - Deep Dive
# 16                           How to fine-tune a LLM?
# 17               Build AI Apps with Google AI Studio
# 18                  Build ChatGPT replica in 1 hour!
# 19  Mastering Audio Models and Voice Cloning with AI
# 20                           Build Your First AI App
# 21  AI & Cybersecurity: Opportunities and Challenges
# 22                Build a Personal Assistant with AI
# 23    Build AI Apps with Google AI Studio! (No-code)
# 24         Crash Course on Building RAG Applications
# 25                  GenAI Rewind ⏪ and 2024 Forecast
# 26              Fine-tuning Llama and Mistral Models
# 27                            Building AI Agents 101
# 28                                Intro to Langchain
# 29                        No-Code AI App development
# 30                   Build ChatGPT Replica in 1 hour
#
#                                      Poster Image URL  \
# 0   /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 1   /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 2   /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 3   /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 4   /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 5   /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 6   /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 7   /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 8   /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 9   /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 10  /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 11  /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 12  /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 13  /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 14  /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 15  /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 16  /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 17  /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 18  /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 19  /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 20  /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 21  /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 22  /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 23  /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 24  /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 25  /_next/image?url=https%3A%2F%2Foukdqujzonxvqhi...
# 26  /_next/image?url=https%3A%2F%2Fauth.buildfastw...
# 27  /_next/image?url=https%3A%2F%2Fauth.buildfastw...
# 28  /_next/image?url=https%3A%2F%2Fauth.buildfastw...
# 29  /_next/image?url=https%3A%2F%2Fauth.buildfastw...
# 30  /_next/image?url=https%3A%2F%2Fauth.buildfastw...
#
#                                         Resource Link  \
# 0   https://www.buildfastwithai.com/resources/info...
# 1   https://www.buildfastwithai.com/resources/info...
# 2   https://www.buildfastwithai.com/resources/info...
# 3   https://www.buildfastwithai.com/resources/info...
# 4   https://www.buildfastwithai.com/resources/info...
# 5   https://www.buildfastwithai.com/resources/info...
# 6   https://www.buildfastwithai.com/resources/info...
# 7   https://www.buildfastwithai.com/resources/info...
# 8   https://www.buildfastwithai.com/resources/info...
# 9   https://www.buildfastwithai.com/resources/info...
# 10  https://www.buildfastwithai.com/resources/info...
# 11  https://www.buildfastwithai.com/resources/info...
# 12  https://www.buildfastwithai.com/resources/info...
# 13  https://www.buildfastwithai.com/resources/info...
# 14  https://www.buildfastwithai.com/resources/info...
# 15  https://www.buildfastwithai.com/resources/info...
# 16  https://www.buildfastwithai.com/resources/info...
# 17  https://www.buildfastwithai.com/resources/info...
# 18  https://www.buildfastwithai.com/resources/info...
# 19  https://www.buildfastwithai.com/resources/info...
# 20  https://www.buildfastwithai.com/resources/info...
# 21  https://www.buildfastwithai.com/resources/info...
# 22  https://www.buildfastwithai.com/resources/info...
# 23  https://www.buildfastwithai.com/resources/info...
# 24  https://www.buildfastwithai.com/resources/info...
# 25  https://www.buildfastwithai.com/resources/info...
# 26  https://www.buildfastwithai.com/resources/info...
# 27  https://www.buildfastwithai.com/resources/info...
# 28  https://www.buildfastwithai.com/resources/info...
# 29  https://www.buildfastwithai.com/resources/info...
# 30  https://www.buildfastwithai.com/resources/info...
#
#                                           Description Price
# 0   Introducing the Generative AI Launchpad, a cou...  Free
# 1   This course covers website development using V...  Free
# 2   Discover how to leverage AI for professional g...  Free
# 3   Empower your job search and career growth with...  Free
# 4   Discover the power of AI-assisted coding with ...  Free
# 5   This hands-on workshop will guide you through ...  Free
# 6   This hands-on workshop explores the integratio...  Free
# 7   This comprehensive course covers essential Pyt...  Free
# 8   This comprehensive course explores the cutting...  Free
# 9   Discover the cutting-edge world of Generative ...  Free
# 10  Discover the cutting-edge capabilities of Clau...  Free
# 11  In this comprehensive course, you will explore...  Free
# 12  This comprehensive session delves into the fas...  Free
# 13  In this course, you will get to know about:\n\...  Free
# 14  Agenda:\n\nAI Tools for Developers: Discover t...  Free
# 15  In this immersive course, our expert panel wil...  Free
# 16  This interactive session is designed for both ...  Free
# 17  Google AI Studio is an amazing web-based edito...  Free
# 18  Throughout the session, you will gain practica...  Free
# 19  Whether you're a developer looking to enhance ...  Free
# 20  In this course, we are going to explore the ba...  Free
# 21  Join our interactive workshop on "AI and Cyber...  Free
# 22  In this course, you will acquire knowledge on ...  Free
# 23  The inception of 'Built Fast Today' and its fo...  Free
# 24  Want to build customized chatbots on your data...  Free
# 25  ​2023 has been a phenomenal year for AI overal...  Free
# 26  Introduced the use of large language models (L...  Free
# 27  In this lecture, we will dive into the world o...  Free
# 28  A langchain is not a recognized term or concep...  Free
# 29  No-code AI app development refers to the proce...  Free
# 30  This lecture will teach you how to build a rep...  Free

# %%
df["Poster Image URL"][0]
# Out:
# '/_next/image?url=https%3A%2F%2Foukdqujzonxvqhiefdsv.supabase.co%2Fstorage%2Fv1%2Fobject%2Fpublic%2Fcourse-videos%2Fthumbnails%2Fonline_events_720.jpg-1735884431061&w=828&q=75'

# %%
df.columns
# Out:
# Index(['Course Name', 'Poster Image URL', 'Resource Link', 'Description',
#        'Price'],
#       dtype='object')

# %%
df=df[['Course Name','Resource Link', 'Description',
       'Price']]

# %%
df
# Out:
#                                          Course Name  \
# 0                   Are you Ready for GenAI in 2025?
# 1                   Build Website in just 20 Minutes
# 2                          Master Automation with AI
# 3                        Elevate Your Resume with AI
# 4                                 Coding with Cursor
# 5                          Create Your Own AI Avatar
# 6                                   Gen AI for Excel
# 7                        Basics of Python for Gen AI
# 8                          Create Your AI Girlfriend
# 9                     Gen AI 2024 Half-yearly Rewind
# 10                                 Claude 3.5 Sonnet
# 11                              Web Scraping with AI
# 12                         Function Calling with LLM
# 13                                 GPT-4o: Deep Dive
# 14                10x Developer Productivity with AI
# 15                               Llama 3 - Deep Dive
# 16                           How to fine-tune a LLM?
# 17               Build AI Apps with Google AI Studio
# 18                  Build ChatGPT replica in 1 hour!
# 19  Mastering Audio Models and Voice Cloning with AI
# 20                           Build Your First AI App
# 21  AI & Cybersecurity: Opportunities and Challenges
# 22                Build a Personal Assistant with AI
# 23    Build AI Apps with Google AI Studio! (No-code)
# 24         Crash Course on Building RAG Applications
# 25                  GenAI Rewind ⏪ and 2024 Forecast
# 26              Fine-tuning Llama and Mistral Models
# 27                            Building AI Agents 101
# 28                                Intro to Langchain
# 29                        No-Code AI App development
# 30                   Build ChatGPT Replica in 1 hour
#
#                                         Resource Link  \
# 0   https://www.buildfastwithai.com/resources/info...
# 1   https://www.buildfastwithai.com/resources/info...
# 2   https://www.buildfastwithai.com/resources/info...
# 3   https://www.buildfastwithai.com/resources/info...
# 4   https://www.buildfastwithai.com/resources/info...
# 5   https://www.buildfastwithai.com/resources/info...
# 6   https://www.buildfastwithai.com/resources/info...
# 7   https://www.buildfastwithai.com/resources/info...
# 8   https://www.buildfastwithai.com/resources/info...
# 9   https://www.buildfastwithai.com/resources/info...
# 10  https://www.buildfastwithai.com/resources/info...
# 11  https://www.buildfastwithai.com/resources/info...
# 12  https://www.buildfastwithai.com/resources/info...
# 13  https://www.buildfastwithai.com/resources/info...
# 14  https://www.buildfastwithai.com/resources/info...
# 15  https://www.buildfastwithai.com/resources/info...
# 16  https://www.buildfastwithai.com/resources/info...
# 17  https://www.buildfastwithai.com/resources/info...
# 18  https://www.buildfastwithai.com/resources/info...
# 19  https://www.buildfastwithai.com/resources/info...
# 20  https://www.buildfastwithai.com/resources/info...
# 21  https://www.buildfastwithai.com/resources/info...
# 22  https://www.buildfastwithai.com/resources/info...
# 23  https://www.buildfastwithai.com/resources/info...
# 24  https://www.buildfastwithai.com/resources/info...
# 25  https://www.buildfastwithai.com/resources/info...
# 26  https://www.buildfastwithai.com/resources/info...
# 27  https://www.buildfastwithai.com/resources/info...
# 28  https://www.buildfastwithai.com/resources/info...
# 29  https://www.buildfastwithai.com/resources/info...
# 30  https://www.buildfastwithai.com/resources/info...
#
#                                           Description Price
# 0   Introducing the Generative AI Launchpad, a cou...  Free
# 1   This course covers website development using V...  Free
# 2   Discover how to leverage AI for professional g...  Free
# 3   Empower your job search and career growth with...  Free
# 4   Discover the power of AI-assisted coding with ...  Free
# 5   This hands-on workshop will guide you through ...  Free
# 6   This hands-on workshop explores the integratio...  Free
# 7   This comprehensive course covers essential Pyt...  Free
# 8   This comprehensive course explores the cutting...  Free
# 9   Discover the cutting-edge world of Generative ...  Free
# 10  Discover the cutting-edge capabilities of Clau...  Free
# 11  In this comprehensive course, you will explore...  Free
# 12  This comprehensive session delves into the fas...  Free
# 13  In this course, you will get to know about:\n\...  Free
# 14  Agenda:\n\nAI Tools for Developers: Discover t...  Free
# 15  In this immersive course, our expert panel wil...  Free
# 16  This interactive session is designed for both ...  Free
# 17  Google AI Studio is an amazing web-based edito...  Free
# 18  Throughout the session, you will gain practica...  Free
# 19  Whether you're a developer looking to enhance ...  Free
# 20  In this course, we are going to explore the ba...  Free
# 21  Join our interactive workshop on "AI and Cyber...  Free
# 22  In this course, you will acquire knowledge on ...  Free
# 23  The inception of 'Built Fast Today' and its fo...  Free
# 24  Want to build customized chatbots on your data...  Free
# 25  ​2023 has been a phenomenal year for AI overal...  Free
# 26  Introduced the use of large language models (L...  Free
# 27  In this lecture, we will dive into the world o...  Free
# 28  A langchain is not a recognized term or concep...  Free
# 29  No-code AI app development refers to the proce...  Free
# 30  This lecture will teach you how to build a rep...  Free

# %%
df.to_csv("Dataset.csv")

# %%
df
# Out:
#                                          Course Name  \
# 0                   Are you Ready for GenAI in 2025?
# 1                   Build Website in just 20 Minutes
# 2                          Master Automation with AI
# 3                        Elevate Your Resume with AI
# 4                                 Coding with Cursor
# 5                          Create Your Own AI Avatar
# 6                                   Gen AI for Excel
# 7                        Basics of Python for Gen AI
# 8                          Create Your AI Girlfriend
# 9                     Gen AI 2024 Half-yearly Rewind
# 10                                 Claude 3.5 Sonnet
# 11                              Web Scraping with AI
# 12                         Function Calling with LLM
# 13                                 GPT-4o: Deep Dive
# 14                10x Developer Productivity with AI
# 15                               Llama 3 - Deep Dive
# 16                           How to fine-tune a LLM?
# 17               Build AI Apps with Google AI Studio
# 18                  Build ChatGPT replica in 1 hour!
# 19  Mastering Audio Models and Voice Cloning with AI
# 20                           Build Your First AI App
# 21  AI & Cybersecurity: Opportunities and Challenges
# 22                Build a Personal Assistant with AI
# 23    Build AI Apps with Google AI Studio! (No-code)
# 24         Crash Course on Building RAG Applications
# 25                  GenAI Rewind ⏪ and 2024 Forecast
# 26              Fine-tuning Llama and Mistral Models
# 27                            Building AI Agents 101
# 28                                Intro to Langchain
# 29                        No-Code AI App development
# 30                   Build ChatGPT Replica in 1 hour
#
#                                         Resource Link  \
# 0   https://www.buildfastwithai.com/resources/info...
# 1   https://www.buildfastwithai.com/resources/info...
# 2   https://www.buildfastwithai.com/resources/info...
# 3   https://www.buildfastwithai.com/resources/info...
# 4   https://www.buildfastwithai.com/resources/info...
# 5   https://www.buildfastwithai.com/resources/info...
# 6   https://www.buildfastwithai.com/resources/info...
# 7   https://www.buildfastwithai.com/resources/info...
# 8   https://www.buildfastwithai.com/resources/info...
# 9   https://www.buildfastwithai.com/resources/info...
# 10  https://www.buildfastwithai.com/resources/info...
# 11  https://www.buildfastwithai.com/resources/info...
# 12  https://www.buildfastwithai.com/resources/info...
# 13  https://www.buildfastwithai.com/resources/info...
# 14  https://www.buildfastwithai.com/resources/info...
# 15  https://www.buildfastwithai.com/resources/info...
# 16  https://www.buildfastwithai.com/resources/info...
# 17  https://www.buildfastwithai.com/resources/info...
# 18  https://www.buildfastwithai.com/resources/info...
# 19  https://www.buildfastwithai.com/resources/info...
# 20  https://www.buildfastwithai.com/resources/info...
# 21  https://www.buildfastwithai.com/resources/info...
# 22  https://www.buildfastwithai.com/resources/info...
# 23  https://www.buildfastwithai.com/resources/info...
# 24  https://www.buildfastwithai.com/resources/info...
# 25  https://www.buildfastwithai.com/resources/info...
# 26  https://www.buildfastwithai.com/resources/info...
# 27  https://www.buildfastwithai.com/resources/info...
# 28  https://www.buildfastwithai.com/resources/info...
# 29  https://www.buildfastwithai.com/resources/info...
# 30  https://www.buildfastwithai.com/resources/info...
#
#                                           Description Price
# 0   Introducing the Generative AI Launchpad, a cou...  Free
# 1   This course covers website development using V...  Free
# 2   Discover how to leverage AI for professional g...  Free
# 3   Empower your job search and career growth with...  Free
# 4   Discover the power of AI-assisted coding with ...  Free
# 5   This hands-on workshop will guide you through ...  Free
# 6   This hands-on workshop explores the integratio...  Free
# 7   This comprehensive course covers essential Pyt...  Free
# 8   This comprehensive course explores the cutting...  Free
# 9   Discover the cutting-edge world of Generative ...  Free
# 10  Discover the cutting-edge capabilities of Clau...  Free
# 11  In this comprehensive course, you will explore...  Free
# 12  This comprehensive session delves into the fas...  Free
# 13  In this course, you will get to know about:\n\...  Free
# 14  Agenda:\n\nAI Tools for Developers: Discover t...  Free
# 15  In this immersive course, our expert panel wil...  Free
# 16  This interactive session is designed for both ...  Free
# 17  Google AI Studio is an amazing web-based edito...  Free
# 18  Throughout the session, you will gain practica...  Free
# 19  Whether you're a developer looking to enhance ...  Free
# 20  In this course, we are going to explore the ba...  Free
# 21  Join our interactive workshop on "AI and Cyber...  Free
# 22  In this course, you will acquire knowledge on ...  Free
# 23  The inception of 'Built Fast Today' and its fo...  Free
# 24  Want to build customized chatbots on your data...  Free
# 25  ​2023 has been a phenomenal year for AI overal...  Free
# 26  Introduced the use of large language models (L...  Free
# 27  In this lecture, we will dive into the world o...  Free
# 28  A langchain is not a recognized term or concep...  Free
# 29  No-code AI app development refers to the proce...  Free
# 30  This lecture will teach you how to build a rep...  Free

# %%
import pandas as pd

# %%
df=pd.read_csv("Dataset.csv")

# %%
df
# Out:
#     Unnamed: 0                                       Course Name  \
# 0            0                  Are you Ready for GenAI in 2025?
# 1            1                  Build Website in just 20 Minutes
# 2            2                         Master Automation with AI
# 3            3                       Elevate Your Resume with AI
# 4            4                                Coding with Cursor
# 5            5                         Create Your Own AI Avatar
# 6            6                                  Gen AI for Excel
# 7            7                       Basics of Python for Gen AI
# 8            8                         Create Your AI Girlfriend
# 9            9                    Gen AI 2024 Half-yearly Rewind
# 10          10                                 Claude 3.5 Sonnet
# 11          11                              Web Scraping with AI
# 12          12                         Function Calling with LLM
# 13          13                                 GPT-4o: Deep Dive
# 14          14                10x Developer Productivity with AI
# 15          15                               Llama 3 - Deep Dive
# 16          16                           How to fine-tune a LLM?
# 17          17               Build AI Apps with Google AI Studio
# 18          18                  Build ChatGPT replica in 1 hour!
# 19          19  Mastering Audio Models and Voice Cloning with AI
# 20          20                           Build Your First AI App
# 21          21  AI & Cybersecurity: Opportunities and Challenges
# 22          22                Build a Personal Assistant with AI
# 23          23    Build AI Apps with Google AI Studio! (No-code)
# 24          24         Crash Course on Building RAG Applications
# 25          25                  GenAI Rewind ⏪ and 2024 Forecast
# 26          26              Fine-tuning Llama and Mistral Models
# 27          27                            Building AI Agents 101
# 28          28                                Intro to Langchain
# 29          29                        No-Code AI App development
# 30          30                   Build ChatGPT Replica in 1 hour
#
#                                         Resource Link  \
# 0   https://www.buildfastwithai.com/resources/info...
# 1   https://www.buildfastwithai.com/resources/info...
# 2   https://www.buildfastwithai.com/resources/info...
# 3   https://www.buildfastwithai.com/resources/info...
# 4   https://www.buildfastwithai.com/resources/info...
# 5   https://www.buildfastwithai.com/resources/info...
# 6   https://www.buildfastwithai.com/resources/info...
# 7   https://www.buildfastwithai.com/resources/info...
# 8   https://www.buildfastwithai.com/resources/info...
# 9   https://www.buildfastwithai.com/resources/info...
# 10  https://www.buildfastwithai.com/resources/info...
# 11  https://www.buildfastwithai.com/resources/info...
# 12  https://www.buildfastwithai.com/resources/info...
# 13  https://www.buildfastwithai.com/resources/info...
# 14  https://www.buildfastwithai.com/resources/info...
# 15  https://www.buildfastwithai.com/resources/info...
# 16  https://www.buildfastwithai.com/resources/info...
# 17  https://www.buildfastwithai.com/resources/info...
# 18  https://www.buildfastwithai.com/resources/info...
# 19  https://www.buildfastwithai.com/resources/info...
# 20  https://www.buildfastwithai.com/resources/info...
# 21  https://www.buildfastwithai.com/resources/info...
# 22  https://www.buildfastwithai.com/resources/info...
# 23  https://www.buildfastwithai.com/resources/info...
# 24  https://www.buildfastwithai.com/resources/info...
# 25  https://www.buildfastwithai.com/resources/info...
# 26  https://www.buildfastwithai.com/resources/info...
# 27  https://www.buildfastwithai.com/resources/info...
# 28  https://www.buildfastwithai.com/resources/info...
# 29  https://www.buildfastwithai.com/resources/info...
# 30  https://www.buildfastwithai.com/resources/info...
#
#                                           Description Price
# 0   Course name is Are you Ready for GenAI in 2025...  Free
# 1   Course name is Build Website in just 20 Minute...  Free
# 2   Course name is Master Automation with AI Disco...  Free
# 3   Course name is Elevate Your Resume with AI Emp...  Free
# 4   Course name is Coding with Cursor Discover the...  Free
# 5   Course name is Create Your Own AI Avatar This ...  Free
# 6   Course name is Gen AI for Excel This hands-on ...  Free
# 7   Course name is Basics of Python for Gen AI Thi...  Free
# 8   Course name is Create Your AI Girlfriend This ...  Free
# 9   Course name is Gen AI 2024 Half-yearly Rewind ...  Free
# 10  Course name is Claude 3.5 Sonnet Discover the ...  Free
# 11  Course name is Web Scraping with AI In this co...  Free
# 12  Course name is Function Calling with LLM This ...  Free
# 13  Course name is GPT-4o: Deep Dive In this cours...  Free
# 14  Course name is 10x Developer Productivity with...  Free
# 15  Course name is Llama 3 - Deep Dive In this imm...  Free
# 16  Course name is How to fine-tune a LLM? This in...  Free
# 17  Course name is Build AI Apps with Google AI St...  Free
# 18  Course name is Build ChatGPT replica in 1 hour...  Free
# 19  Course name is Mastering Audio Models and Voic...  Free
# 20  Course name is Build Your First AI App In this...  Free
# 21  Course name is AI & Cybersecurity: Opportuniti...  Free
# 22  Course name is Build a Personal Assistant with...  Free
# 23  Course name is Build AI Apps with Google AI St...  Free
# 24  Course name is Crash Course on Building RAG Ap...  Free
# 25  Course name is GenAI Rewind ⏪ and 2024 Forecas...  Free
# 26  Course name is Fine-tuning Llama and Mistral M...  Free
# 27  Course name is Building AI Agents 101 In this ...  Free
# 28  Course name is Intro to Langchain A langchain ...  Free
# 29  Course name is No-Code AI App development No-c...  Free
# 30  Course name is Build ChatGPT Replica in 1 hour...  Free

# %%
def transform(row):
    return row["Course Name"] + " " + row["Description"]

df["Description"] = df.apply(transform, axis=1)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_12624\2099590833.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Description"] = df.apply(transform, axis=1)

# %%
df["Description"]
# Out:
# 0     Are you Ready for GenAI in 2025? Introducing t...
# 1     Build Website in just 20 Minutes This course c...
# 2     Master Automation with AI Discover how to leve...
# 3     Elevate Your Resume with AI Empower your job s...
# 4     Coding with Cursor Discover the power of AI-as...
# 5     Create Your Own AI Avatar This hands-on worksh...
# 6     Gen AI for Excel This hands-on workshop explor...
# 7     Basics of Python for Gen AI This comprehensive...
# 8     Create Your AI Girlfriend This comprehensive c...
# 9     Gen AI 2024 Half-yearly Rewind Discover the cu...
# 10    Claude 3.5 Sonnet Discover the cutting-edge ca...
# 11    Web Scraping with AI In this comprehensive cou...
# 12    Function Calling with LLM This comprehensive s...
# 13    GPT-4o: Deep Dive In this course, you will get...
# 14    10x Developer Productivity with AI Agenda:\n\n...
# 15    Llama 3 - Deep Dive In this immersive course, ...
# 16    How to fine-tune a LLM? This interactive sessi...
# 17    Build AI Apps with Google AI Studio Google AI ...
# 18    Build ChatGPT replica in 1 hour! Throughout th...
# 19    Mastering Audio Models and Voice Cloning with ...
# 20    Build Your First AI App In this course, we are...
# 21    AI & Cybersecurity: Opportunities and Challeng...
# 22    Build a Personal Assistant with AI In this cou...
# 23    Build AI Apps with Google AI Studio! (No-code)...
# 24    Crash Course on Building RAG Applications Want...
# 25    GenAI Rewind ⏪ and 2024 Forecast ​2023 has bee...
# 26    Fine-tuning Llama and Mistral Models Introduce...
# 27    Building AI Agents 101 In this lecture, we wil...
# 28    Intro to Langchain A langchain is not a recogn...
# 29    No-Code AI App development No-code AI app deve...
# 30    Build ChatGPT Replica in 1 hour This lecture w...
# Name: Description, dtype: object

# %%
df.columns
# Out:
# Index(['Course Name', 'Resource Link', 'Description', 'Price'], dtype='object')

# %%
df=df[['Course Name', 'Resource Link', 'Description', 'Price']]

# %%
df
# Out:
#                                          Course Name  \
# 0                   Are you Ready for GenAI in 2025?
# 1                   Build Website in just 20 Minutes
# 2                          Master Automation with AI
# 3                        Elevate Your Resume with AI
# 4                                 Coding with Cursor
# 5                          Create Your Own AI Avatar
# 6                                   Gen AI for Excel
# 7                        Basics of Python for Gen AI
# 8                          Create Your AI Girlfriend
# 9                     Gen AI 2024 Half-yearly Rewind
# 10                                 Claude 3.5 Sonnet
# 11                              Web Scraping with AI
# 12                         Function Calling with LLM
# 13                                 GPT-4o: Deep Dive
# 14                10x Developer Productivity with AI
# 15                               Llama 3 - Deep Dive
# 16                           How to fine-tune a LLM?
# 17               Build AI Apps with Google AI Studio
# 18                  Build ChatGPT replica in 1 hour!
# 19  Mastering Audio Models and Voice Cloning with AI
# 20                           Build Your First AI App
# 21  AI & Cybersecurity: Opportunities and Challenges
# 22                Build a Personal Assistant with AI
# 23    Build AI Apps with Google AI Studio! (No-code)
# 24         Crash Course on Building RAG Applications
# 25                  GenAI Rewind ⏪ and 2024 Forecast
# 26              Fine-tuning Llama and Mistral Models
# 27                            Building AI Agents 101
# 28                                Intro to Langchain
# 29                        No-Code AI App development
# 30                   Build ChatGPT Replica in 1 hour
#
#                                         Resource Link  \
# 0   https://www.buildfastwithai.com/resources/info...
# 1   https://www.buildfastwithai.com/resources/info...
# 2   https://www.buildfastwithai.com/resources/info...
# 3   https://www.buildfastwithai.com/resources/info...
# 4   https://www.buildfastwithai.com/resources/info...
# 5   https://www.buildfastwithai.com/resources/info...
# 6   https://www.buildfastwithai.com/resources/info...
# 7   https://www.buildfastwithai.com/resources/info...
# 8   https://www.buildfastwithai.com/resources/info...
# 9   https://www.buildfastwithai.com/resources/info...
# 10  https://www.buildfastwithai.com/resources/info...
# 11  https://www.buildfastwithai.com/resources/info...
# 12  https://www.buildfastwithai.com/resources/info...
# 13  https://www.buildfastwithai.com/resources/info...
# 14  https://www.buildfastwithai.com/resources/info...
# 15  https://www.buildfastwithai.com/resources/info...
# 16  https://www.buildfastwithai.com/resources/info...
# 17  https://www.buildfastwithai.com/resources/info...
# 18  https://www.buildfastwithai.com/resources/info...
# 19  https://www.buildfastwithai.com/resources/info...
# 20  https://www.buildfastwithai.com/resources/info...
# 21  https://www.buildfastwithai.com/resources/info...
# 22  https://www.buildfastwithai.com/resources/info...
# 23  https://www.buildfastwithai.com/resources/info...
# 24  https://www.buildfastwithai.com/resources/info...
# 25  https://www.buildfastwithai.com/resources/info...
# 26  https://www.buildfastwithai.com/resources/info...
# 27  https://www.buildfastwithai.com/resources/info...
# 28  https://www.buildfastwithai.com/resources/info...
# 29  https://www.buildfastwithai.com/resources/info...
# 30  https://www.buildfastwithai.com/resources/info...
#
#                                           Description Price
# 0   Are you Ready for GenAI in 2025? Introducing t...  Free
# 1   Build Website in just 20 Minutes This course c...  Free
# 2   Master Automation with AI Discover how to leve...  Free
# 3   Elevate Your Resume with AI Empower your job s...  Free
# 4   Coding with Cursor Discover the power of AI-as...  Free
# 5   Create Your Own AI Avatar This hands-on worksh...  Free
# 6   Gen AI for Excel This hands-on workshop explor...  Free
# 7   Basics of Python for Gen AI This comprehensive...  Free
# 8   Create Your AI Girlfriend This comprehensive c...  Free
# 9   Gen AI 2024 Half-yearly Rewind Discover the cu...  Free
# 10  Claude 3.5 Sonnet Discover the cutting-edge ca...  Free
# 11  Web Scraping with AI In this comprehensive cou...  Free
# 12  Function Calling with LLM This comprehensive s...  Free
# 13  GPT-4o: Deep Dive In this course, you will get...  Free
# 14  10x Developer Productivity with AI Agenda:\n\n...  Free
# 15  Llama 3 - Deep Dive In this immersive course, ...  Free
# 16  How to fine-tune a LLM? This interactive sessi...  Free
# 17  Build AI Apps with Google AI Studio Google AI ...  Free
# 18  Build ChatGPT replica in 1 hour! Throughout th...  Free
# 19  Mastering Audio Models and Voice Cloning with ...  Free
# 20  Build Your First AI App In this course, we are...  Free
# 21  AI & Cybersecurity: Opportunities and Challeng...  Free
# 22  Build a Personal Assistant with AI In this cou...  Free
# 23  Build AI Apps with Google AI Studio! (No-code)...  Free
# 24  Crash Course on Building RAG Applications Want...  Free
# 25  GenAI Rewind ⏪ and 2024 Forecast ​2023 has bee...  Free
# 26  Fine-tuning Llama and Mistral Models Introduce...  Free
# 27  Building AI Agents 101 In this lecture, we wil...  Free
# 28  Intro to Langchain A langchain is not a recogn...  Free
# 29  No-Code AI App development No-code AI app deve...  Free
# 30  Build ChatGPT Replica in 1 hour This lecture w...  Free
